# %%
import pandas as pd
import os

#
# Path to unzipped GTFS files
data_path = "../data/static/unpacked/"  # Adjust if needed

# Load core GTFS files
agency = pd.read_csv(os.path.join(data_path, "agency.txt"))
calendar_dates = pd.read_csv(os.path.join(data_path, "calendar_dates.txt"))
calendar = pd.read_csv(os.path.join(data_path, "calendar.txt"))
routes = pd.read_csv(os.path.join(data_path, "routes.txt"))
shapes = pd.read_csv(os.path.join(data_path, "shapes.txt"))
stop_times = pd.read_csv(os.path.join(data_path, "stop_times.txt"))
stops = pd.read_csv(os.path.join(data_path, "stops.txt"))
transfers = pd.read_csv(os.path.join(data_path, "transfers.txt"))
trips = pd.read_csv(os.path.join(data_path, "trips.txt"))

# Display the first few rows of Routes  
routes.head()
# Out:
#   agency_id route_id route_short_name            route_long_name  route_type  \
# 0  MTA NYCT        1                1  Broadway - 7 Avenue Local           1
# 1  MTA NYCT        2                2           7 Avenue Express           1
# 2  MTA NYCT        3                3           7 Avenue Express           1
# 3  MTA NYCT        4                4   Lexington Avenue Express           1
# 4  MTA NYCT        5                5   Lexington Avenue Express           1
#
#                                           route_desc  \
# 0  Trains operate between 242 St in the Bronx and...
# 1  Trains operate between Wakefield-241 St, Bronx...
# 2  Trains operate between 148 St, 7 Av, Manhattan...
# 3  Trains operate daily between Woodlawn/Jerome A...
# 4  Weekdays daytime, most trains operate between ...
#
#                                         route_url route_color route_text_color
# 0  http://web.mta.info/nyct/service/pdf/t1cur.pdf      EE352E              NaN
# 1  http://web.mta.info/nyct/service/pdf/t2cur.pdf      EE352E              NaN
# 2  http://web.mta.info/nyct/service/pdf/t3cur.pdf      EE352E              NaN
# 3  http://web.mta.info/nyct/service/pdf/t4cur.pdf      00933C              NaN
# 4  http://web.mta.info/nyct/service/pdf/t5cur.pdf      00933C              NaN

# %%
routes["route_id"].nunique()
# Out:
# 30

# %%
trips_merged = trips.merge(routes, on="route_id")
trips_merged[["trip_id", "route_id", "route_long_name", "direction_id"]].head()
# Out:
#                                   trip_id route_id            route_long_name  \
# 0  AFA23GEN-1038-Sunday-00_000600_1..S03R        1  Broadway - 7 Avenue Local
# 1  AFA23GEN-1038-Sunday-00_002600_1..S03R        1  Broadway - 7 Avenue Local
# 2  AFA23GEN-1038-Sunday-00_004600_1..S03R        1  Broadway - 7 Avenue Local
# 3  AFA23GEN-1038-Sunday-00_006600_1..S03R        1  Broadway - 7 Avenue Local
# 4  AFA23GEN-1038-Sunday-00_007200_1..N03R        1  Broadway - 7 Avenue Local
#
#    direction_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             0

# %%
sample_trip_id = trips["trip_id"].iloc[0]
sample_stop_times = stop_times[stop_times["trip_id"] == sample_trip_id]
sample_stop_times = sample_stop_times.merge(stops, on="stop_id")

sample_stop_times[["stop_sequence", "stop_name", "arrival_time", "departure_time"]].sort_values("stop_sequence")
# Out:
#     stop_sequence                   stop_name arrival_time departure_time
# 0               1   Van Cortlandt Park-242 St     00:06:00       00:06:00
# 1               2                      238 St     00:07:30       00:07:30
# 2               3                      231 St     00:09:00       00:09:00
# 3               4          Marble Hill-225 St     00:10:30       00:10:30
# 4               5                      215 St     00:12:00       00:12:00
# 5               6                      207 St     00:13:00       00:13:00
# 6               7                  Dyckman St     00:14:30       00:14:30
# 7               8                      191 St     00:16:00       00:16:00
# 8               9                      181 St     00:17:30       00:17:30
# 9              10       168 St-Washington Hts     00:19:30       00:19:30
# 10             11                      157 St     00:21:00       00:21:00
# 11             12                      145 St     00:23:00       00:23:00
# 12             13         137 St-City College     00:24:30       00:24:30
# 13             14                      125 St     00:26:00       00:26:00
# 14             15  116 St-Columbia University     00:28:30       00:28:30
# 15             16     Cathedral Pkwy (110 St)     00:29:30       00:29:30
# 16             17                      103 St     00:30:30       00:30:30
# 17             18                       96 St     00:32:30       00:32:30
# 18             19                       86 St     00:34:30       00:34:30
# 19             20                       79 St     00:35:30       00:35:30
# 20             21                       72 St     00:37:00       00:37:00
# 21             22        66 St-Lincoln Center     00:38:30       00:38:30
# 22             23       59 St-Columbus Circle     00:40:00       00:40:00
# 23             24                       50 St     00:42:00       00:42:00
# 24             25              Times Sq-42 St     00:43:30       00:43:30
# 25             26          34 St-Penn Station     00:45:00       00:45:00
# 26             27                       28 St     00:46:00       00:46:00
# 27             28                       23 St     00:47:00       00:47:00
# 28             29                       18 St     00:48:00       00:48:00
# 29             30                       14 St     00:49:00       00:49:00
# 30             31  Christopher St-Sheridan Sq     00:50:30       00:50:30
# 31             32                  Houston St     00:52:00       00:52:00
# 32             33                    Canal St     00:54:00       00:54:00
# 33             34                 Franklin St     00:55:00       00:55:00
# 34             35                 Chambers St     00:56:00       00:59:00
# 35             36               WTC Cortlandt     01:00:30       01:00:30
# 36             37                   Rector St     01:02:00       01:02:00
# 37             38                 South Ferry     01:04:00       01:04:00

# %%
import folium

# Build a map centered at the first stop
first_stop = sample_stop_times.iloc[0]
m = folium.Map(location=[first_stop["stop_lat"], first_stop["stop_lon"]], zoom_start=12)

# Plot all stops on the trip
for _, row in sample_stop_times.iterrows():
    folium.CircleMarker(
        location=[row["stop_lat"], row["stop_lon"]],
        radius=4,
        popup=row["stop_name"],
        color='blue',
        fill=True,
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b75dd7eb8fb20570385f1097e7e26a6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b75dd7eb8fb20570385f1097e7e26a6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b75dd7eb8fb20570385f1097e7e26a6e = L.map(
#                 &quot;map_b75dd7eb8fb20570385f1097e7e26a6e&quot;,
#                 {
#                     center: [40.889248, -73.898583],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35250af710f65025e8b15bf1e03bf24b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_35250af710f65025e8b15bf1e03bf24b.addTo(map_b75dd7eb8fb20570385f1097e7e26a6e);
#
#
#             var circle_marker_7292531efde3986a385c667b12dbbcfe = L.circleMarker(
#                 [40.889248, -73.898583],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b75dd7eb8fb20570385f1097e7e26a6e);
#
#
#         var popup_72ac9d9229a2328edd54edd0f4beb37f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79ace091a9f44af6b33114c6c23500e3 = $(`&lt;div id=&quot;html_79ace091a9f44af6b33114c6c23500e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Van Cortlandt Park-242 St&lt;/div&gt;`)[0];
#                 popup_72ac9d9229a2328edd54edd0f4beb37f.setContent(html_79ace091a9f44af6b33114c6c23500e3);
#
#
#
#         circle_marker_7292531efde3986a385c667b12dbbcfe.bindPopup(popup_72ac9d9229a2328edd54edd0f4beb37f)
#         ;
#
#
#
#
#             var circle_marker_943c72c638efba0fef31bbc8cb1bb83e = L.circleMarker(
#                 [40.884667, -73.90087],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b75dd7eb8fb20570385f1097e7e26a6e);
#
#
#         var popup_172cab1f33fffb3f0023107aa0c67bfd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf40bd65c4d1ec64f262842a1c1d885b = $(`&lt;div id=&quot;html_bf40bd65c4d1ec64f262842a1c1d885b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;238 St&lt;/div&gt;`)[0];
#                 popup_172cab1f33fffb3f0023107aa0c67bfd.setContent(html_bf40bd65c4d1ec64f262842a1c1d885b);
#
#
#
#         circle_marker_943c72c638efba0fef31bbc8cb1bb83e.bindPopup(popup_172cab1f33fffb3f0023107aa0c67bfd)
#         ;
#
#
#
#
#             var circle_marker_6eb619b220b679e41e73c9c46c59f091 = L.circleMarker(
#                 [40.878856, -73.904834],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b75dd7eb8fb20570385f1097e7e26a6e);
#
#
#         var popup_6299469dcf1a1a1a991a791b553e5d8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80d770bd58815037f6bb460629e4c06d = $(`&lt;div id=&quot;html_80d770bd58815037f6bb460629e4c06d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;231 St&lt;/div&gt;`)[0];
#                 popup_6299469dcf1a1a1a991a791b553e5d8b.setContent(html_80d770bd58815037f6bb460629e4c06d);
#
#
#
#         circle_marker_6eb619b220b679e41e73c9c46c59f091.bindPopup(popup_6299469dcf1a1a1a991a791b553e5d8b)
#         ;
#
#
#
#
#             var circle_marker_1b3e80080273c4e44499714ecdb704e0 = L.circleMarker(
#                 [40.874561, -73.909831],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillCol

# %%
# Choose a route and get one of its shape_ids
sample_route_id = "A"  # change this to any route you want
sample_trip = trips[trips["route_id"] == sample_route_id].iloc[0]
sample_shape_id = sample_trip["shape_id"]
sample_shape_id
# Out:
# 'A..S74R'

# %%
# Extract shape data and sort by sequence
shape_data = shapes[shapes["shape_id"] == sample_shape_id].sort_values("shape_pt_sequence")
shape_data.head()
# Out:
#       shape_id  shape_pt_sequence  shape_pt_lat  shape_pt_lon
# 82204  A..S74R                  0     40.868072    -73.919899
# 82205  A..S74R                  1     40.867859    -73.920698
# 82206  A..S74R                  2     40.867846    -73.920742
# 82207  A..S74R                  3     40.867833    -73.920786
# 82208  A..S74R                  4     40.867819    -73.920831

# %%
# Extract shape data and sort by sequence
shape_data = shapes[shapes["shape_id"] == sample_shape_id].sort_values("shape_pt_sequence")
shape_data.head()
# Out:
#       shape_id  shape_pt_sequence  shape_pt_lat  shape_pt_lon
# 82204  A..S74R                  0     40.868072    -73.919899
# 82205  A..S74R                  1     40.867859    -73.920698
# 82206  A..S74R                  2     40.867846    -73.920742
# 82207  A..S74R                  3     40.867833    -73.920786
# 82208  A..S74R                  4     40.867819    -73.920831

# %%
import folium

# Center the map at the first point
start_lat = shape_data.iloc[0]["shape_pt_lat"]
start_lon = shape_data.iloc[0]["shape_pt_lon"]
m = folium.Map(location=[start_lat, start_lon], zoom_start=12)

# Create polyline for the full route
points = shape_data[["shape_pt_lat", "shape_pt_lon"]].values.tolist()
folium.PolyLine(points, color="blue", weight=3).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6309cd4de651051845d1020f0a23fca2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6309cd4de651051845d1020f0a23fca2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6309cd4de651051845d1020f0a23fca2 = L.map(
#                 &quot;map_6309cd4de651051845d1020f0a23fca2&quot;,
#                 {
#                     center: [40.868072, -73.919899],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4cbb6b55a6646dc205c65e3277de7c48 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_
939141], [40.843061, -73.939152], [40.843, -73.939163], [40.842941, -73.939173], [40.842882, -73.939181], [40.842825, -73.939189], [40.842768, -73.939196], [40.842713, -73.939202], [40.842305, -73.939259], [40.84224, -73.939262], [40.842176, -73.939267], [40.842113, -73.939271], [40.84205, -73.939277], [40.841987, -73.939284], [40.841926, -73.939291], [40.841864, -73.939299], [40.841804, -73.939307], [40.841744, -73.939317], [40.841684, -73.939327], [40.841625, -73.939338], [40.841567, -73.93935], [40.841509, -73.939363], [40.841452, -73.939376], [40.841395, -73.93939], [40.840719, -73.939561], [40.840083, -73.939735], [40.84003, -73.93975], [40.839977, -73.939764], [40.839923, -73.939778], [40.839869, -73.93979], [40.839815, -73.939802], [40.83976, -73.939814], [40.839705, -73.939824], [40.839649, -73.939834], [40.839593, -73.939843], [40.839537, -73.939851], [40.83948, -73.939858], [40.8 ...

# %%
# Use the same sample_trip from earlier
sample_trip_id = sample_trip["trip_id"]

# Get stop_times for that trip and merge with stop coordinates
trip_stops = stop_times[stop_times["trip_id"] == sample_trip_id].sort_values("stop_sequence")
trip_stops = trip_stops.merge(stops, on="stop_id")

trip_stops[["stop_sequence", "stop_name", "stop_lat", "stop_lon"]].head()
# Out:
#    stop_sequence      stop_name   stop_lat   stop_lon
# 0              1  Inwood-207 St  40.868072 -73.919899
# 1              2     Dyckman St  40.865491 -73.927271
# 2              3         190 St  40.859022 -73.934180
# 3              4         181 St  40.851695 -73.937969
# 4              5         175 St  40.847391 -73.939704

# %%
import folium

# Start the map at the first shape point
m = folium.Map(location=[shape_data.iloc[0]["shape_pt_lat"], shape_data.iloc[0]["shape_pt_lon"]], zoom_start=12)

# Add the route shape
points = shape_data[["shape_pt_lat", "shape_pt_lon"]].values.tolist()
folium.PolyLine(points, color="blue", weight=3).add_to(m)

# Add stops as circle markers
for _, row in trip_stops.iterrows():
    folium.CircleMarker(
        location=[row["stop_lat"], row["stop_lon"]],
        radius=5,
        popup=row["stop_name"],
        color="red",
        fill=True,
        fill_opacity=0.8,
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11f069def06ad5d318b5d2dd66fe808c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11f069def06ad5d318b5d2dd66fe808c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11f069def06ad5d318b5d2dd66fe808c = L.map(
#                 &quot;map_11f069def06ad5d318b5d2dd66fe808c&quot;,
#                 {
#                     center: [40.868072, -73.919899],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9596d14730793e8464c0182522ad273 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c9596d14730793e8464c0182522ad273.addTo(map_11f069def06ad5d318b5d2dd66fe808c);
#
#
#             var poly_line_82e92f53dd4d957d6855fe974c6360f2 = L.polyline(
#                 [[40.868072, -73.919899], [40.867859, -73.920698], [40.867846, -73.920742], [40.867833, -73.920786], [40.867819, -73.920831], [40.867806, -73.920875], [40.867791, -73.92092], [40.867777, -73.920965], [40.867762, -73.92101], [40.867747, -73.921056], [40.867732, -73.921101], [40.867717, -73.921147], [40.867701, -73.921193], [40.867685, -73.92124], [40.867669, -73.921286], [40.867652, -73.921333], [40.867635, -73.92138], [40.865884, -73.926267], [40.865859, -73.926338], [40.865833, -73.926408], [40.865808, -73.926478], [40.865782, -73.926547], [40.865756, -73.926616], [40.86573, -73.926684], [40.865704, -73.926751], [40.865678, -73.926818], [40.865652, -73.926885], [40.865625, -73.926